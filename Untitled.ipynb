# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\vd.gokkulkumar\\Documents\\learning\\Consumer_Complaints.csv")
# Out:
# c:\users\vd.gokkulkumar\pycharmprojects\pythonproject\venv\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (5,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#        Date received                  Product  \
# 0         07/29/2013            Consumer Loan
# 1         07/29/2013  Bank account or service
# 2         07/29/2013  Bank account or service
# 3         07/29/2013  Bank account or service
# 4         07/29/2013                 Mortgage
# ...              ...                      ...
# 670593    11/16/2016         Credit reporting
# 670594    10/26/2016                 Mortgage
# 670595    11/17/2016         Credit reporting
# 670596    09/22/2016              Credit card
# 670597    08/13/2016            Consumer Loan
#
#                                    Sub-product  \
# 0                                 Vehicle loan
# 1                             Checking account
# 2                             Checking account
# 3                             Checking account
# 4                  Conventional fixed mortgage
# ...                                        ...
# 670593                                     NaN
# ...

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df['count'] = 1
df
# Out:
#        Date received                  Product  \
# 0         07/29/2013            Consumer Loan
# 1         07/29/2013  Bank account or service
# 2         07/29/2013  Bank account or service
# 3         07/29/2013  Bank account or service
# 4         07/29/2013                 Mortgage
# ...              ...                      ...
# 670593    11/16/2016         Credit reporting
# 670594    10/26/2016                 Mortgage
# 670595    11/17/2016         Credit reporting
# 670596    09/22/2016              Credit card
# 670597    08/13/2016            Consumer Loan
#
#                                    Sub-product  \
# 0                                 Vehicle loan
# 1                             Checking account
# 2                             Checking account
# 3                             Checking account
# 4                  Conventional fixed mortgage
# ...                                        ...
# 670593                                     NaN
# ...

# %%
df.pivot_table
